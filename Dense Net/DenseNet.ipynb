# %%
from google.colab import drive
drive.mount('/content/drive')

FOLDERNAME = 'learn'
assert FOLDERNAME is not None, "error"

import sys
sys.path.append('/content/drive/My drive/{}'.format(FOLDERNAME))

# %cd /content/drive/My\ Drive /%FOLDERNAME/datasets/
# !bash get_datasets.sh
# %cd /content/drive/My\ Drive/%FOLDERNAME
# Out:
# Mounted at /content/drive
# [Errno 2] No such file or directory: '/content/drive/My Drive /%FOLDERNAME/datasets/'
# /content
# bash: get_datasets.sh: No such file or directory
# [Errno 2] No such file or directory: '/content/drive/My Drive/%FOLDERNAME'
# /content

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torch.utils.data import sampler

import torchvision.datasets as dset
import torchvision.transforms as T
import torch.nn.functional as F
import numpy as np
USE_GPU = True
dtype = torch.float
if USE_GPU and torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

print_every = 100
print('using device:', device)
# Out:
# using device: cuda

# %%
NUM_TRAIN = 49000
transform = T.Compose([
    T.ToTensor(),
    T.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
])
cifar10_train = dset.CIFAR10('./datasets', train=True, download=True,
                             transform=transform)
loader_train = DataLoader(cifar10_train, batch_size=64,
                          sampler=sampler.SubsetRandomSampler(range(NUM_TRAIN)))
cifar10_val = dset.CIFAR10('./datasets', train=True, download=True,
                             transform=transform)
loader_val = DataLoader(cifar10_train, batch_size = 64,
                          sampler=sampler.SubsetRandomSampler(range(NUM_TRAIN, 50000)))

cifar10_test = dset.CIFAR10('./datasets', train=False, download=True,
                             transform=transform)
loader_test = DataLoader(cifar10_test, batch_size = 64)
# Out:
# 100%|██████████| 170M/170M [00:16<00:00, 10.6MB/s]

# %%
def check_accuracy(loader, model):
  if loader.dataset.train:
    print('Checking accuracy on validation set')
  else:
    print('Checking accuracy on test set')

  num_correct = 0
  num_samples = 0
  model.eval()
  with torch.no_grad():
    for x, y in loader:
      x = x.to(device=device, dtype=dtype)
      y = y.to(device=device, dtype=dtype)
      scores = model(x)
      _, preds = scores.max(1)
      num_correct += (preds==y).sum()
      num_samples += preds.size(0)
    acc = float(num_correct) / num_samples
    print('Got %d / %d correct (%.2f)' % (num_correct, num_samples, 100*acc))

# %%
def train(model, params, epochs=1):
  model = model.to(device=device)
  for e in range(epochs):
    print(f"epoch {e+1} / {epochs}:")
    for t, (x, y) in enumerate(loader_train):
      model.train()
      x = x.to(device=device, dtype=dtype)
      y = y.to(device=device, dtype=torch.long)

      scores = model(x)
      loss = F.cross_entropy(scores, y)

      optimizer.zero_grad()
      loss.backward()
      optimizer.step()

      if t % print_every == 0:
        print('Iteration %d, loss = %.4f' % (t, loss.item()))
        check_accuracy(loader_val, model)
        print()

# %%
torch.manual_seed(42)

class MLPNet(nn.Module):
  def __init__(self, input_size, hidden_size, num_classes):
    super().__init__()
    self.w1 = nn.Linear(input_size, hidden_size[0], bias=True)
    self.w2 = nn.Linear(hidden_size[0], hidden_size[1], bias=True)
    self.w3 = nn.Linear(hidden_size[1], hidden_size[2], bias=True)
    self.w4 = nn.Linear(hidden_size[2], num_classes, bias=True)
    self.flatten = nn.Flatten()

  def forward(self, x):
    x = self.flatten(x)
    x = F.relu(self.w1(x))
    x = F.relu(self.w2(x))
    x = F.relu(self.w3(x))
    scores = self.w4(x)
    return scores

def testMLP():
  input_size = 50
  hidden_size = [100, 100, 100]
  x = torch.zeros((64, input_size), dtype=dtype)
  model = MLPNet(input_size, hidden_size, 10)
  scores = model(x)
  print(scores.size())
testMLP()
# Out:
# torch.Size([64, 10])

# %%
learning_rate = 1e-3
hidden_size = [128, 128, 64]

model = MLPNet(3 * 32 * 32, hidden_size, 10)
optimizer = optim.AdamW(model.parameters(), lr=learning_rate)

train(model, optimizer)
# Out:
# epoch 1 / 1:
# Iteration 0, loss = 2.3268
# Checking accuracy on validation set
# Got 120 / 1000 correct (12.00)
#
# Iteration 100, loss = 1.6313
# Checking accuracy on validation set
# Got 365 / 1000 correct (36.50)
#
# Iteration 200, loss = 1.8362
# Checking accuracy on validation set
# Got 395 / 1000 correct (39.50)
#
# Iteration 300, loss = 1.4359
# Checking accuracy on validation set
# Got 411 / 1000 correct (41.10)
#
# Iteration 400, loss = 1.7349
# Checking accuracy on validation set
# Got 408 / 1000 correct (40.80)
#
# Iteration 500, loss = 1.4389
# Checking accuracy on validation set
# Got 453 / 1000 correct (45.30)
#
# Iteration 600, loss = 1.7878
# Checking accuracy on validation set
# Got 461 / 1000 correct (46.10)
#
# Iteration 700, loss = 1.5371
# Checking accuracy on validation set
# Got 465 / 1000 correct (46.50)

# %%
class ConvNet(nn.Module):
  def __init__(self, in_channel, channel_1, channel_2, num_classes):
    super().__init__()
    self.conv1 = nn.Conv2d(in_channel, channel_1, 5, padding=2, bias=True)
    self.conv2 = nn.Conv2d(channel_1, channel_2, 3, padding=1, bias=True)
    self.flatten = nn.Flatten()
    self.fc = nn.Linear(channel_2 * 32 * 32, num_classes, bias=False)

  def forward(self,x):
    x = self.conv2(F.relu(self.conv1(x)))
    x = F.relu(x)
    x = self.flatten(x)
    out = self.fc(x)
    return out

def testConvNet():
  in_channel, channel_1, channel_2, num_classes = 3, 16, 16, 10
  model = ConvNet(in_channel, channel_1, channel_2, num_classes)
  x = torch.zeros((64, 3, 32, 32), dtype=dtype)
  scores = model(x)
  print(scores.size())
testConvNet()
# Out:
# torch.Size([64, 10])

# %%
learning_rate = 9e-4
in_channel, channel_1, channel_2, num_classes = 3, 64, 32, 10

model = ConvNet(in_channel, channel_1, channel_2, num_classes)
optimizer = optim.AdamW(model.parameters(), lr=learning_rate)

train(model, optimizer)
# Out:
# epoch 1 / 1:
# Iteration 0, loss = 2.3414
# Checking accuracy on validation set
# Got 123 / 1000 correct (12.30)
#
# Iteration 100, loss = 1.8324
# Checking accuracy on validation set
# Got 437 / 1000 correct (43.70)
#
# Iteration 200, loss = 1.5288
# Checking accuracy on validation set
# Got 441 / 1000 correct (44.10)
#
# Iteration 300, loss = 1.1818
# Checking accuracy on validation set
# Got 497 / 1000 correct (49.70)
#
# Iteration 400, loss = 1.6356
# Checking accuracy on validation set
# Got 512 / 1000 correct (51.20)
#
# Iteration 500, loss = 1.4074
# Checking accuracy on validation set
# Got 560 / 1000 correct (56.00)
#
# Iteration 600, loss = 1.3649
# Checking accuracy on validation set
# Got 562 / 1000 correct (56.20)
#
# Iteration 700, loss = 1.3823
# Checking accuracy on validation set
# Got 567 / 1000 correct (56.70)

# %%
from collections import OrderedDict

class Transition(nn.Sequential):
  def __init__(self, in_channel, out_channel):
    super().__init__()
    self.add_module('norm', nn.BatchNorm2d(in_channel))
    self.add_module('relu', nn.ReLU(inplace=True))
    self.add_module('conv', nn.Conv2d(in_channel, out_channel, 1, bias=False))
    self.add_module('pool', nn.AvgPool2d(2, 2))

# %%
class DenseLayer(nn.Module):
  def __init__(self, in_channel, growth_rate, bottleneck_size, drop_rate):
    super().__init__()
    self.norm1 = nn.BatchNorm2d(in_channel)
    self.relu1 = nn.ReLU(inplace=True)
    self.conv1 = nn.Conv2d(in_channel, growth_rate*bottleneck_size, 1, bias=False)

    self.norm2 = nn.BatchNorm2d(growth_rate*bottleneck_size)
    self.relu2 = nn.ReLU(inplace=True)
    self.conv2 = nn.Conv2d(growth_rate*bottleneck_size, growth_rate, 3, padding=1, bias=False)

    self.dropout = float(drop_rate)

  def forward(self, x):
    x = [x] if torch.is_tensor(x) else x
    x = self.conv1(self.relu1(self.norm1(torch.cat(x, 1))))
    output = self.conv2(self.relu2(self.norm2(x)))

    if self.dropout > 0:
      output = F.dropout(output, p=self.dropout, training=self.training)

    return output

# %%
class DenseBlock(nn.ModuleDict):
  def __init__(self, num_layers, in_channel, growth_rate, bottleneck_size, drop_rate):
    super().__init__()
    for i in range(num_layers):
      layer = DenseLayer(in_channel + i*growth_rate, growth_rate, bottleneck_size, drop_rate)
      self.add_module(f'denselayer{i+1}', layer)

  def forward(self,x):
    xs = [x]
    for name, layer in self.items():
      x_new = layer(xs)
      xs.append(x_new)

    return torch.cat(xs,1)

# %%
class DenseNet(nn.Module):
  def __init__(self, in_channel=32, growth_rate=16, bottleneck_size=4,
               block_config=(6,12,8), drop_rate=0, num_classes=10):
    super().__init__()
    self.features = nn.Sequential(OrderedDict([
        ('conv0', nn.Conv2d(3, in_channel, 7, padding=3, bias=False)),
        ('norm0', nn.BatchNorm2d(in_channel)),
        ('relu0', nn.ReLU(inplace=True)),
    ]))
    num_features = in_channel
    for i, num_layers in enumerate(block_config):
      block = DenseBlock(num_layers, num_features, growth_rate, bottleneck_size, drop_rate)
      self.features.add_module(f'denseblock{i+1}', block)
      num_features += num_layers * growth_rate

      if i!= len(block_config) - 1:
        trans = Transition(num_features, num_features // 2)
        self.features.add_module(f'transition{i+1}', trans)
        num_features = num_features // 2

    self.features.add_module(f'norm{i+2}', nn.BatchNorm2d(num_features))
    self.features.add_module(f'relu{i+2}', nn.ReLU(inplace=True))
    self.fc = nn.Linear(num_features, num_classes)
    self.flatten = nn.Flatten()
    for m in self.modules():
      if isinstance(m, nn.Conv2d):
        nn.init.kaiming_normal_(m.weight)
      elif isinstance(m, nn.BatchNorm2d):
        nn.init.constant_(m.weight, 1)
        nn.init.constant_(m.bias, 0)
      elif isinstance(m, nn.Linear):
        nn.init.constant_(m.bias, 0)

  def forward(self, x):
    out = F.adaptive_avg_pool2d(self.features(x), (1, 1))
    out = self.fc(self.flatten(out))

    return out

# %%
def testDenseNet():
  model = DenseNet()
  x = torch.zeros((64, 3, 32, 32), dtype=dtype)
  scores = model(x)
  print(scores.size())
testDenseNet()
# Out:
# torch.Size([64, 10])

# %%
learning_rate = 2e-4

model = DenseNet().to(device)
optimizer = optim.AdamW(model.parameters(), lr=learning_rate)

train(model, optimizer, epochs=20)
# Out:
# epoch 1 / 20:
# Iteration 0, loss = 2.2961
# Checking accuracy on validation set
# Got 132 / 1000 correct (13.20)
#
# Iteration 100, loss = 1.8829
# Checking accuracy on validation set
# Got 363 / 1000 correct (36.30)
#
# Iteration 200, loss = 1.6674
# Checking accuracy on validation set
# Got 403 / 1000 correct (40.30)
#
# Iteration 300, loss = 1.5245
# Checking accuracy on validation set
# Got 442 / 1000 correct (44.20)
#
# Iteration 400, loss = 1.4496
# Checking accuracy on validation set
# Got 467 / 1000 correct (46.70)
#
# Iteration 500, loss = 1.4042
# Checking accuracy on validation set
# Got 508 / 1000 correct (50.80)
#
# Iteration 600, loss = 1.3717
# Checking accuracy on validation set
# Got 519 / 1000 correct (51.90)
#
# Iteration 700, loss = 1.3722
# Checking accuracy on validation set
# Got 532 / 1000 correct (53.20)
#
# epoch 2 / 20:
# Iteration 0, loss = 1.2395
# Checking accuracy on validation set
# Got 544 / 1000 correct (54.40)
#
# Iteration 100, loss = 1.3114
# Checking accuracy on validation set
# Got 545 / 1000 correct (54.50)
#
# Iteration 200, loss = 1.1783
# Checking accuracy on validation set
# Got 582 / 1000 correct (58.20)
#
# Iteration 300, loss = 1.0782
# Checking accuracy on validation set
# Got 579 / 1000 correct (57.90)
#
# Iteration 400, loss = 0.9362
# Checking accuracy on validation set
# Got 614 / 1000 correct (61.40)
#
# Iteration 500, loss = 1.0325
# Checking accuracy on validation set
# Got 595 / 1000 correct (59.50)
#
# Iteration 600, loss = 1.0813
# Checking accuracy on validation set
# Got 606 / 1000 correct (60.60)
#
# Iteration 700, loss = 1.0658
# Checking accuracy on validation set
# Got 608 / 1000 correct (60.80)
#
# epoch 3 / 20:
# Iteration 0, loss = 0.9927
# Checking accuracy on validation set
# Got 620 / 1000 correct (62.00)
#
# Iteration 100, loss = 1.1336
# Checking accuracy on validation set
# Got 638 / 1000 correct (63.80)
#
# Iteration 200, loss = 0.9666
# Checking accuracy on validation set
# Got 626 / 1000 correct (62.60)
#
# Iteration 300, loss = 1.0757
# Checking accuracy on validation set
# Got 608 / 1000 correct (60.80)
#
# Iteration 400, loss = 0.9999
# Checking accuracy on validation set
# Got 664 / 1000 correct (66.40)
#
# Iteration 500, loss = 0.9217
# Checking accuracy on validation set
# Got 647 / 1000 correct (64.70)
#
# Iteration 600, loss = 1.0726
# Checking accuracy on validation set
# Got 641 / 1000 correct (64.10)
#
# Iteration 700, loss = 0.9068
# Checking accuracy on validation set
# Got 664 / 1000 correct (66.40)
#
# epoch 4 / 20:
# Iteration 0, loss = 0.9026
# Checking accuracy on validation set
# Got 673 / 1000 correct (67.30)
#
# Iteration 100, loss = 0.7828
# Checking accuracy on validation set
# Got 657 / 1000 correct (65.70)
#
# Iteration 200, loss = 0.8174
# Checking accuracy on validation set
# Got 652 / 1000 correct (65.20)
#
# Iteration 300, loss = 0.9810
# Checking accuracy on validation set
# Got 668 / 1000 correct (66.80)
#
# Iteration 400, loss = 0.8397
# Checking accuracy on validation set
# Got 671 / 1000 correct (67.10)
#
# Iteration 500, loss = 0.8840
# Checking accuracy on validation set
# Got 631 / 1000 correct (63.10)
#
# Iteration 600, loss = 1.0038
# Checking accuracy on validation set
# Got 672 / 1000 correct (67.20)
#
# Iteration 700, loss = 0.7839
# Checking accuracy on validation set
# Got 688 / 1000 correct (68.80)
#
# epoch 5 / 20:
# Iteration 0, loss = 0.7514
# Checking accuracy on validation set
# Got 653 / 1000 correct (65.30)
#
# Iteration 100, loss = 0.6652
# Checking accuracy on validation set
# Got 681 / 1000 correct (68.10)
#
# Iteration 200, loss = 0.6849
# Checking accuracy on validation set
# Got 702 / 1000 correct (70.20)
#
# Iteration 300, loss = 0.8236
# Checking accuracy on validation set
# Got 678 / 1000 correct (67.80)
#
# Iteration 400, loss = 0.7655
# Checking accuracy on validation set
# Got 681 / 1000 correct (68.10)
#
# Iteration 500, loss = 0.8327
# Checking accuracy on validation set
# Got 683 / 1000 correct (68.30)
#
# Iteration 600, loss = 0.8197
# Checking accuracy on validation set
# Got 693 / 1000 correct (69.30)
#
# Iteration 700, loss = 0.7951
# Checking accuracy on validation set
# Got 681 / 1000 correct (68.10)
#
# epoch 6 / 20:
# Iteration 0, loss = 0.6824
# Checking accuracy on validation set
# Got 698 / 1000 correct (69.80)
#
# Iteration 100, loss = 0.5730
# Checking accuracy on validation set
# Got 682 / 1000 correct (68.20)
#
# Iteration 200, loss = 0.6338
# Checking accuracy on validation set
# Got 696 / 1000 correct (69.60)
#
# Iteration 300, loss = 0.7654
# Checking accuracy on validation set
# Got 707 / 1000 correct (70.70)
#
# Iteration 400, loss = 0.6955
# Checking accuracy on validation set
# Got 688 / 1000 correct (68.80)
#
# Iteration 500, loss = 0.8026
# Checking accuracy on validation set
# Got 709 / 1000 correct (70.90)
#
# Iteration 600, loss = 0.4541
# Checking accuracy on validation set
# Got 696 / 1000 correct (69.60)
#
# Iteration 700, loss = 0.6280
# Checking accuracy on validation set
# Got 716 / 1000 correct (71.60)
#
# epoch 7 / 20:
# Iteration 0, loss = 0.5737
# Checking accuracy on validation set
# Got 672 / 1000 correct (67.20)
#
# Iteration 100, loss = 0.5965
# Checking accuracy on validation set
# Got 709 / 1000 correct (70.90)
#
# Iteration 200, loss = 0.5218
# Checking accuracy on validation set
# Got 715 / 1000 correct (71.50)
#
# Iteration 300, loss = 0.7418
# Checking accuracy on validation set
# Got 708 / 1000 correct (70.80)
#
# Iteration 400, loss = 0.5783
# Checking accuracy on validation set
# Got 702 / 1000 correct (70.20)
#
# Iteration 500, loss = 0.7073
# Checking accuracy on validation set
# Got 719 / 1000 correct (71.90)
#
# Iteration 600, loss = 0.7379
# Checking accuracy on validation set
# Got 705 / 1000 correct (70.50)
#
# Iteration 700, loss = 0.6833
# Checking accuracy on validation set
# Got 716 / 1000 correct (71.60)
#
# epoch 8 / 20:
# Iteration 0, loss = 0.5208
# Checking accuracy on validation set
# Got 714 / 1000 correct (71.40)
#
# Iteration 100, loss = 0.4510
# Checking accuracy on validation set
# Got 732 / 1000 correct (73.20)
#
# Iteration 200, loss = 0.6087
# Checking accuracy on validation set
# Got 698 / 1000 correct (69.80)
#
# Iteration 300, loss = 0.6357
# Checking accuracy on validation set
# Got 723 / 1000 correct (72.30)
#
# Iteration 400, loss = 0.7207
# Checking accuracy on validation set
# Got 714 / 1000 correct (71.40)
#
# Iteration 500, loss = 0.5667
# Checking accuracy on validation set
# Got 714 / 1000 correct (71.40)
#
# Iteration 600, loss = 0.5088
# Checking accuracy on validation set
# Got 709 / 1000 correct (70.90)
#
# Iteration 700, loss = 0.5834
# Checking accuracy on validation set
# Got 726 / 1000 correct (72.60)
#
# epoch 9 / 20:
# Iteration 0, loss = 0.3894
# Checking accuracy on validation set
# Got 713 / 1000 correct (71.30)
#
# Iteration 100, loss = 0.3723
# Checking accuracy on validation set
# Got 724 / 1000 correct (72.40)
#
# Iteration 200, loss = 0.4137
# Checking accuracy on validation set
# Got 740 / 1000 correct (74.00)
#
# Iteration 300, loss = 0.4556
# Checking accuracy on validation set
# Got 743 / 1000 correct (74.30)
#
# Iteration 400, loss = 0.4372
# Checking accuracy on validation set
# Got 715 / 1000 correct (71.50)
#
# Iteration 500, loss = 0.4505
# Checking accuracy on validation set
# Got 734 / 1000 correct (73.40)
#
# Iteration 600, loss = 0.7631
# Checking accuracy on validation set
# Got 732 / 1000 correct (73.20)
#
# Iteration 700, loss = 0.4004
# Checking accuracy on validation set
# Got 739 / 1000 correct (73.90)
#
# epoch 10 / 20:
# Iteration 0, loss = 0.5730
# Checking accuracy on validation set
# Got 721 / 1000 correct (72.10)
#
# Iteration 100, loss = 0.3542
# Checking accuracy on validation set
# Got 725 / 1000 correct (72.50)
#
# Iteration 200, loss = 0.4352
# Checking accuracy on validation set
# Got 712 / 1000 correct (71.20)
#
# Iteration 300, loss = 0.3511
# Checking accuracy on validation set
# Got 745 / 1000 correct (74.50)
#
# Iteration 400, loss = 0.4571
# Checking accuracy on validation set
# Got 717 / 1000 correct (71.70)
#
# Iteration 500, loss = 0.4088
# Checking accuracy on validation set
# Got 741 / 1000 correct (74.10)
#
# Iteration 600, loss = 0.3776
# Checking accuracy on validation set
# Got 758 / 1000 correct (75.80)
#
# Iteration 700, loss = 0.5364
# Checking accuracy on validation set
# Got 751 / 1000 correct (75.10)
#
# epoch 11 / 20:
# Iteration 0, loss = 0.3965
# Checking accuracy on validation set
# Got 723 / 1000 correct (72.30)
#
# Iteration 100, loss = 0.3434
# Checking accuracy on validation set
# Got 744 / 1000 correct (74.40)
#
# Iteration 200, loss = 0.2690
# Checking accuracy on validation set
# Got 718 / 1000 correct (71.80)
#
# Iteration 300, loss = 0.3762
# Checking accuracy on validation set
# Got 727 / 1000 correct (72.70)
#
# Iteration 400, loss = 0.4772
# Checking accuracy on validation set
# Got 722 / 1000 correct (72.20)
#
# Iteration 500, loss = 0.4121
# Checking accuracy on validation set
# Got 725 / 1000 correct (72.50)
#
# Iteration 600, loss = 0.3444
# Checking accuracy on validation set
# Got 747 / 1000 correct (74.70)
#
# Iteration 700, loss = 0.3868
# Checking accuracy on validation set
# Got 738 / 1000 correct (73.80)
#
# epoch 12 / 20:
# Iteration 0, loss = 0.2265
# Checking accuracy on validation set
# Got 719 / 1000 correct (71.90)
#
# Iteration 100, loss = 0.3647
# Checking accuracy on validation set
# Got 757 / 1000 correct (75.70)
#
# Iteration 200, loss = 0.6426
# Checking accuracy on validation set
# Got 744 / 1000 correct (74.40)
#
# Iteration 300, loss = 0.2799
# Checking accuracy on validation set
# Got 730 / 1000 correct (73.00)
#
# Iteration 400, loss = 0.2356
# Checking accuracy on validation set
# Got 726 / 1000 correct (72.60)
#
# Iteration 500, loss = 0.3824
# Checking accuracy on validation set
# Got 739 / 1000 correct (73.90)
#
# Iteration 600, loss = 0.3491
# Checking accuracy on validation set
# Got 745 / 1000 correct (74.50)
#
# Iteration 700, loss = 0.2835
# Checking accuracy on validation set
# Got 726 / 1000 correct (72.60)
#
# epoch 13 / 20:
# Iteration 0, loss = 0.4685
# Checking accuracy on validation set
# Got 741 / 1000 correct (74.10)
#
# Iteration 100, loss = 0.3845
# Checking accuracy on validation set
# Got 754 / 1000 correct (75.40)
#
# Iteration 200, loss = 0.2974
# Checking accuracy on validation set
# Got 728 / 1000 correct (72.80)
#
# Iteration 300, loss = 0.2265
# Checking accuracy on validation set
# Got 748 / 1000 correct (74.80)
#
# Iteration 400, loss = 0.2727
# Checking accuracy on validation set
# Got 751 / 1000 correct (75.10)
#
# Iteration 500, loss = 0.2747
# Checking accuracy on validation set
# Got 717 / 1000 correct (71.70)
#
# Iteration 600, loss = 0.2876
# Checking accuracy on validation set
# Got 722 / 1000 correct (72.20)
#
# Iteration 700, loss = 0.2753
# Checking accuracy on validation set
# Got 719 / 1000 correct (71.90)
#
# epoch 14 / 20:
# Iteration 0, loss = 0.2137
# Checking accuracy on validation set
# Got 741 / 1000 correct (74.10)
#
# Iteration 100, loss = 0.3630
# Checking accuracy on validation set
# Got 753 / 1000 correct (75.30)
#
# Iteration 200, loss = 0.2569
# Checking accuracy on validation set
# Got 703 / 1000 correct (70.30)
#
# Iteration 300, loss = 0.3590
# Checking accuracy on validation set
# Got 744 / 1000 correct (74.40)
#
# Iteration 400, loss = 0.1431
# Checking accuracy on validation set
# Got 754 / 1000 correct (75.40)
#
# Iteration 500, loss = 0.2128
# Checking accuracy on validation set
# Got 761 / 1000 correct (76.10)
#
# Iteration 600, loss = 0.2262
# Checking accuracy on validation set
# Got 745 / 1000 correct (74.50)
#
# Iteration 700, loss = 0.3584
# Checking accuracy on validation set
# Got 733 / 1000 correct (73.30)
#
# epoch 15 / 20:
# Iteration 0, loss = 0.2925
# Checking accuracy on validation set
# Got 739 / 1000 correct (73.90)
#
# Iteration 100, loss = 0.1746
# Checking accuracy on validation set
# Got 726 / 1000 correct (72.60)
#
# Iteration 200, loss = 0.2709
# Checking accuracy on validation set
# Got 740 / 1000 correct (74.00)
#
# Iteration 300, loss = 0.1537
# Checking accuracy on validation set
# Got 738 / 1000 correct (73.80)
#
# Iteration 400, loss = 0.1418
# Checking accuracy on validation set
# Got 717 / 1000 correct (71.70)
#
# Iteration 500, loss = 0.1596
# Checking accuracy on validation set
# Got 761 / 1000 correct (76.10)
#
# Iteration 600, loss = 0.3283
# Checking accuracy on validation set
# Got 743 / 1000 correct (74.30)
#
# Iteration 700, loss = 0.2507
# Checking accuracy on validation set
# Got 742 / 1000 correct (74.20)
#
# epoch 16 / 20:
# Iteration 0, loss = 0.2010
# Checking accuracy on validation set
# Got 726 / 1000 correct (72.60)
#
# Iteration 100, loss = 0.2442
# Checking accuracy on validation set
# Got 741 / 1000 correct (74.10)
#
# Iteration 200, loss = 0.2179
# Checking accuracy on validation set
# Got 746 / 1000 correct (74.60)
#
# Iteration 300, loss = 0.1874
# Checking accuracy on validation set
# Got 736 / 1000 correct (73.60)
#
# Iteration 400, loss = 0.2991
# Checking accuracy on validation set
# Got 716 / 1000 correct (71.60)
#
# Iteration 500, loss = 0.1503
# Checking accuracy on validation set
# Got 737 / 1000 correct (73.70)
#
# Iteration 600, loss = 0.3387
# Checking accuracy on validation set
# Got 739 / 1000 correct (73.90)
#
# Iteration 700, loss = 0.2873
# Checking accuracy on validation set
# Got 741 / 1000 correct (74.10)
#
# epoch 17 / 20:
# Iteration 0, loss = 0.1288
# Checking accuracy on validation set
# Got 737 / 1000 correct (73.70)
#
# Iteration 100, loss = 0.1377
# Checking accuracy on validation set
# Got 740 / 1000 correct (74.00)
#
# Iteration 200, loss = 0.0926
# Checking accuracy on validation set
# Got 732 / 1000 correct (73.20)
#
# Iteration 300, loss = 0.1706
# Checking accuracy on validation set
# Got 740 / 1000 correct (74.00)
#
# Iteration 400, loss = 0.2456
# Checking accuracy on validation set
# Got 755 / 1000 correct (75.50)
#
# Iteration 500, loss = 0.1646
# Checking accuracy on validation set
# Got 742 / 1000 correct (74.20)
#
# Iteration 600, loss = 0.2345
# Checking accuracy on validation set
# Got 735 / 1000 correct (73.50)
#
# Iteration 700, loss = 0.4000
# Checking accuracy on validation set
# Got 737 / 1000 correct (73.70)
#
# epoch 18 / 20:
# Iteration 0, loss = 0.1898
# Checking accuracy on validation set
# Got 749 / 1000 correct (74.90)
#
# Iteration 100, loss = 0.1320
# Checking accuracy on validation set
# Got 740 / 1000 correct (74.00)
#
# Iteration 200, loss = 0.1353
# Checking accuracy on validation set
# Got 745 / 1000 correct (74.50)
#
# Iteration 300, loss = 0.1108
# Checking accuracy on validation set
# Got 736 / 1000 correct (73.60)
#
# Iteration 400, loss = 0.3344
# Checking accuracy on validation set
# Got 739 / 1000 correct (73.90)
#
# Iteration 500, loss = 0.1266
# Checking accuracy on validation set
# Got 755 / 1000 correct (75.50)
#
# Iteration 600, loss = 0.1638
# Checking accuracy on validation set
# Got 733 / 1000 correct (73.30)
#
# Iteration 700, loss = 0.1241
# Checking accuracy on validation set
# Got 716 / 1000 correct (71.60)
#
# epoch 19 / 20:
# Iteration 0, loss = 0.1874
# Checking accuracy on validation set
# Got 716 / 1000 correct (71.60)
#
# Iteration 100, loss = 0.2523
# Checking accuracy on validation set
# Got 720 / 1000 correct (72.00)
#
# Iteration 200, loss = 0.1830
# Checking accuracy on validation set
# Got 746 / 1000 correct (74.60)
#
# Iteration 300, loss = 0.0816
# Checking accuracy on validation set
# Got 745 / 1000 correct (74.50)
#
# Iteration 400, loss = 0.1102
# Checking accuracy on validation set
# Got 742 / 1000 correct (74.20)
#
# Iteration 500, loss = 0.1247
# Checking accuracy on validation set
# Got 747 / 1000 correct (74.70)
#
# Iteration 600, loss = 0.1895
# Checking accuracy on validation set
# Got 744 / 1000 correct (74.40)
#
# Iteration 700, loss = 0.1440
# Checking accuracy on validation set
# Got 752 / 1000 correct (75.20)
#
# epoch 20 / 20:
# Iteration 0, loss = 0.0735
# Checking accuracy on validation set
# Got 748 / 1000 correct (74.80)
#
# Iteration 100, loss = 0.0921
# Checking accuracy on validation set
# Got 739 / 1000 correct (73.90)
#
# Iteration 200, loss = 0.0784
# Checking accuracy on validation set
# Got 748 / 1000 correct (74.80)
#
# Iteration 300, loss = 0.0610
# Checking accuracy on validation set
# Got 749 / 1000 correct (74.90)
#
# Iteration 400, loss = 0.1420
# Checking accuracy on validation set
# Got 717 / 1000 correct (71.70)
#
# Iteration 500, loss = 0.1978
# Checking accuracy on validation set
# Got 736 / 1000 correct (73.60)
#
# Iteration 600, loss = 0.1012
# Checking accuracy on validation set
# Got 697 / 1000 correct (69.70)
#
# Iteration 700, loss = 0.1035
# Checking accuracy on validation set
# Got 714 / 1000 correct (71.40)

# %%
check_accuracy(loader_val, model)
# Out:
# Checking accuracy on validation set
# Got 739 / 1000 correct (73.90)
